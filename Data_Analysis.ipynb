# %% [markdown]
# # MARTin: Analysis of Repeated Measurements
# The following lines of code extract measurements taken with MARTin out of the root export folder.
#
# This Data will then be translated into an object-oriented structure for further processing.

# %%
import os
import json
import statistics
import pandas as pd
from datetime import datetime 
from IPython.display import display

# %% [markdown]
# ### Class: Project
# This class stores all measurements that belong to a project, in this case a project is the same as a participant.
#
# In our specific case a session always contains ten measurements, one participant (or project) has five sessions.
#
# The session start times have to be stored separately since they had to be extracted manually from the logfiles.
# Times can be read out automatically since MARTin generates a timestamp at the point of each measurement.

# %%
class Project:
    def __init__(self, name, sessions = [], sessionStartTimes = []):
        self.name = name
        self.sessions = sessions
        self.sessionStartTimes = sessionStartTimes
    
    # Calculates the average time a measurement takes for each session.
    def getAverageMeasurementDurations(self):
        avgMesurementDurations = []
        for i, session in enumerate(self.sessions):
            lastMeasurementTime = datetime.strptime(self.sessionStartTimes[i], "%H:%M:%S")
            
            timeDeltas = []
            for measurement in session:
                if not measurement.excludedFlag:
                    timeDelta = datetime.strptime(measurement.timestamp, "%H:%M:%S") - lastMeasurementTime
                    timeDeltas.append(timeDelta.total_seconds())
                lastMeasurementTime = datetime.strptime(measurement.timestamp, "%H:%M:%S")
            
            
            avgMesurementDurations.append(sum(timeDeltas)/len(timeDeltas))
        return avgMesurementDurations
    
    # This calculates the standard deviation across the ten individual measurement of an individual session.
    def getMeasurementDurationsStDevs(self):
        mesurementDurationStDevs = []
        for i, session in enumerate(self.sessions):
            lastMeasurementTime = datetime.strptime(self.sessionStartTimes[i], "%H:%M:%S")
            
            timeDeltas = []
            for measurement in session:
                if(not measurement.excludedFlag):
                    timeDelta = datetime.strptime(measurement.timestamp, "%H:%M:%S") - lastMeasurementTime
                    timeDeltas.append(timeDelta.total_seconds())
                    
                lastMeasurementTime = datetime.strptime(measurement.timestamp, "%H:%M:%S")
            
            
            mesurementDurationStDevs.append(statistics.stdev(timeDeltas))
        return mesurementDurationStDevs
            
    # This calls the compare function for each individual session.
    def compareInSets(self):
        compSession = []
        avgMeasurementDurations = self.getAverageMeasurementDurations()
        mesurementDurationStDevs = self.getMeasurementDurationsStDevs()
        
        for i, session in enumerate(self.sessions):
            compSession.append(compare(session, avgMeasurementDurations[i],mesurementDurationStDevs[i]))
        
        return compSession
    
    # This calls compareInSets and calculates the average across all sets.
    def getSessionAverage(self):
        compSession = self.compareInSets()        
        return getDictAvg(compSession)
    
    # This calls the compare function across all sessions.
    def compareAcrossSets(self):
        dataset = []
        avgMeasurementDurations = self.getAverageMeasurementDurations()
        
        for session in self.sessions:
            dataset+= session
        # Here we calculate the StDev across the duration averages
        return compare(dataset, sum(avgMeasurementDurations)/len(avgMeasurementDurations), statistics.stdev(avgMeasurementDurations))

# %% [markdown]
# ### Function: compare
#
# This function contains the main elements of our data analysis.
#
# Given a list of measurements this calculates the relative- and absolute standard deviations for each spot index across all elements of the list.
#
# Finally the calculated values for each spot index will be averaged and returned as a dictionary.

# %%
def compare(dataset, avgMeasurementDuration, measurementDurationStDev): 
    normalized = []
    minimum = []
    maximum = []
    mean = []
    xPos = []
    yPos = []
    
    # This sets our lists to the same length as a measurement.
    for spot in dataset[0].measureData:
        normalized.append([])
        minimum.append([])
        maximum.append([])
        mean.append([])
        xPos.append([])
        yPos.append([])
    
    # This puts all spot values of the same index in the same list.
    for measurement in dataset:
        if(not measurement.excludedFlag):
            for i, spot in enumerate(measurement.measureData):
                normalized[i].append(spot.normalized_mean)
                minimum[i].append(spot.minPixelValue)
                maximum[i].append(spot.maxPixelValue)
                mean[i].append(spot.mean)
                xPos[i].append(spot.xPos)
                yPos[i].append(spot.yPos)       

    avg_normalized = []
    avg_minimum = []
    avg_maximum = []
    avg_mean = []
    avg_xPos = []
    avg_yPos = []

    median_normalized = []
    median_minimum = []
    median_maximum = []
    median_mean = []
    median_xPos = []
    median_yPos = []

    stDev_normalized = []
    stDev_minimum = []
    stDev_maximum = []
    stDev_mean = []
    stDev_xPos = []
    stDev_yPos = []

    stDev_perc_normalized = []
    stDev_perc_minimum = []
    stDev_perc_maximum = []
    stDev_perc_mean = []
    # Positional Data is only calculated in absolute values and therefore not listed.
    
    # Each spot position has its statistically relevant values calculated.
    for counter, pos in enumerate(normalized):
        avg_normalized.append(sum(pos)/len(pos))
        avg_minimum.append(sum(minimum[counter])/len(minimum[counter]))
        avg_maximum.append(sum(maximum[counter])/len(maximum[counter]))
        avg_mean.append(sum(mean[counter])/len(mean[counter]))
        avg_xPos.append(sum(xPos[counter])/len(xPos[counter]))
        avg_yPos.append(sum(yPos[counter])/len(yPos[counter]))

        median_normalized.append(statistics.median(pos))
        median_minimum.append(statistics.median(minimum[counter]))
        median_maximum.append(statistics.median(maximum[counter]))
        median_mean.append(statistics.median(mean[counter]))
        median_xPos.append(statistics.median(xPos[counter]))
        median_yPos.append(statistics.median(yPos[counter]))

        stDev_normalized.append(statistics.stdev(pos))
        stDev_minimum.append(statistics.stdev(minimum[counter]))
        stDev_maximum.append(statistics.stdev(maximum[counter]))
        stDev_mean.append(statistics.stdev(mean[counter]))
        stDev_xPos.append(statistics.stdev(xPos[counter]))
        stDev_yPos.append(statistics.stdev(yPos[counter]))

        if(avg_normalized[counter] > 0):
            stDev_perc_normalized.append(stDev_normalized[counter] / avg_normalized[counter])
        else:
            stDev_perc_normalized.append(0)

        if(avg_minimum[counter] > 0):
            stDev_perc_minimum.append(stDev_minimum[counter] / avg_minimum[counter])
        else:
            stDev_perc_minimum.append(0)

        if(avg_maximum[counter] > 0):
            stDev_perc_maximum.append(stDev_maximum[counter] / avg_maximum[counter])
        else:
            stDev_perc_maximum.append(0)

        if(avg_mean[counter] > 0):
            stDev_perc_mean.append(stDev_mean[counter] / avg_mean[counter])
        else:
            stDev_perc_mean.append(0)
    
    # Only the average of the relevant values are then put into a dictionary and returned.
    resultDict = {
    #'min_StDev': sum(stDev_minimum)/len(stDev_minimum),
    'Minimum pixel value rel. StDev [%]': sum(stDev_perc_minimum)/len(stDev_perc_minimum)*100,
    #'max_StDev': sum(stDev_maximum)/len(stDev_maximum),
    'Maximum pixel value rel. StDev [%]': sum(stDev_perc_maximum)/len(stDev_perc_maximum)*100,
    #'mean_StDev': sum(stDev_mean)/len(stDev_mean),
    'Mean pixel value rel. StDev [%]': sum(stDev_perc_mean)/len(stDev_perc_mean)*100,
    'X-coordinate StDev [px]': sum(stDev_xPos)/len(stDev_xPos),
    'Y-coordinate StDev [px]': sum(stDev_yPos)/len(stDev_yPos),
    'Average duration [sec]': avgMeasurementDuration,
    'Duration StDev [sec]': measurementDurationStDev
    }
    return resultDict

# %% [markdown]
# ### Class: Measurement
# Instances of this class store all values of an individual measurement.

# %%
class Measurement:
    def __init__(self, mId, timestamp, excludedFlag, measureData):
        self.mId = mId
        time = ""
        self.excludedFlag = excludedFlag
        extract = False
        
        # This extracts the measuring time from the timestamp.
        # Adimttedly this is not a very nice way of solving this, but it works for our purposes (directly instanciating into a datetime object had its issues).
        for sign in timestamp:
            if sign == ".":
                extract = False
            if extract:
                time += sign
            if sign == "T":
                extract = True
 
        self.timestamp = time       
        self.measureData = measureData

# %% [markdown]
# ### Class: RawDatapoint
#
# Tis is a value class containing all attributes of an individual spot of a measurement.

# %%
class RawDatapoint:
    def __init__(self, xPos, yPos, minPixelValue, maxPixelValue, mean, std_deviation, mean_minus_min, normalized_mean):
        self.xPos = xPos
        self.yPos = yPos
        self.minPixelValue = minPixelValue
        self.maxPixelValue = maxPixelValue
        self.mean = mean
        self.std_deviation = std_deviation
        self.mean_minus_min = mean_minus_min
        self.normalized_mean = normalized_mean

# %% [markdown]
# ### Function: ReadoutMetadata
# This extracts relevant information from the metadata-file of a measurement.

# %%
def readoutMetadata(metadataPath):
    with open(metadataPath) as metadataJson:
        metadata = json.load(metadataJson)

        mId = metadata["patient"]["id"]
        timestamp = metadata["datetime"]

    return mId, timestamp

# %% [markdown]
# ### Function: ReadoutRawData
# This extracts relevant information of a measurement and creates a list of instances of RawDataPoint containing the corresponding values.

# %%
def readoutRawData(rawDataPath, parametersPath):
    measureData = []
    with open(rawDataPath) as rawDataJson:
        with open(parametersPath) as parametersJson:
            rawData = json.load(rawDataJson)
            parameters = json.load(parametersJson)
            
            for i, spot in enumerate(rawData["values"]):
                xPos = parameters["spots"][i]["position"][0]
                yPos = parameters["spots"][i]["position"][1]
                minPixelValue = spot["min"]
                maxPixelValue = spot["max"]
                mean = spot["mean"]
                std_deviation = spot["std_deviation"]
                mean_minus_min = spot["mean_minus_min"]
                normalized_mean = spot["normalized_mean"]
                
                measureData.append(RawDatapoint(xPos, yPos, minPixelValue, maxPixelValue, mean, std_deviation, mean_minus_min, normalized_mean))
    
    return measureData

# %% [markdown]
# ### Function: Readout
# This function extracts all measurements out of a given directory and returns them as instances of Measurement.

# %%
def readout (path):
    projects = []
    sessions = []
    nMeasurementsExcluded = 0
    excludedFlag = False
    for projIndex, proj in enumerate(os.listdir(path)):

        projects.append(Project(proj))

        for date in os.listdir(os.path.join(path, proj)):
            session = []
            
            for measurement in os.listdir(os.path.join(path, proj, date)):
                if os.path.isdir(os.path.join(path, proj, date, measurement)):
                        # Excluded measurements contain significant errors that were made during the measurement.
                        if("EXCLUDED" in measurement):
                            nMeasurementsExcluded += 1
                            excludedFlag = True
                        else:
                            excludedFlag = False
                        
                        measurementDir = os.path.join(path, proj, date, measurement)

                        mId, timestamp = readoutMetadata(os.path.join(measurementDir, "metadata.json"))
                        session.append(Measurement(mId, timestamp, excludedFlag, readoutRawData(os.path.join(measurementDir,"data.json"), os.path.join(measurementDir, "parameters.json"))))
                    
                        
            sessions.append(session)
            
        projects[projIndex].sessions = sessions.copy()
        sessions.clear()
    
    print ("Number of excluded measurements: " + str(nMeasurementsExcluded))
    return projects

# %% [markdown]
# ### Function: getDictAvg
# Given a list of dictionaries with the same keys, this function calculates the average for each value of the same key and returns a dictionary containing these averages.

# %%
def getDictAvg(dictList):
    avgDict = dict.fromkeys(dictList[0].keys(),0)
    
    for d in dictList:
        for key in avgDict.keys():
            avgDict[key] += d[key]

    for key in avgDict.keys():
        avgDict[key] /= len(dictList)
    
    return avgDict

# %%
# Path of the root folder of the measurements
dPath = ""
projects = readout(dPath)

# Start times were extracted manually from the logfiles for each measuring session.
startTimes = [["19:59:07", "13:18:42", "13:35:08", "12:08:12", "11:43:06"],
                ["18:03:23", "17:37:04", "17:29:05", "19:20:30", "17:01:30"],
                ["20:11:30", "22:09:00", "14:10:00", "18:14:30", "17:03:00"],
                ["20:54:22", "20:59:24", "23:14:27", "18:06:36", "17:47:20"],
                ["20:54:35", "19:59:26", "22:14:41", "17:06:33", "16:47:04"],
                ["20:09:50", "23:03:31", "21:59:35", "23:10:41", "19:55:10"],
                ["17:39:00", "19:05:29", "22:22:58", "21:19:55", "17:36:20"],
                ["20:49:22", "22:39:30", "20:47:50", "23:37:12", "08:49:02"]]

mixxedDataset = [] # Effectively combination of all measurements into one big session.
tableData = [] # Data that will be put in the DataFrame
tableIndices = [] # Row names for our DataFrame
avgDurations = []
sessionAverages = []

for i, proj in enumerate(projects):
    proj.sessionStartTimes = startTimes[i]
    avgDurations += proj.getAverageMeasurementDurations()
    
    tableData += proj.compareInSets()
    
    sessionAvg = proj.getSessionAverage()
    tableData.append(sessionAvg)
    sessionAverages.append(sessionAvg)
    
    tableData.append(proj.compareAcrossSets())
    for session in proj.sessions:
        mixxedDataset += session
    
# This calculates the stDev across all set averages
tableData.append(getDictAvg(sessionAverages))
tableData.append(compare(mixxedDataset, sum(avgDurations) / len(avgDurations), statistics.stdev(avgDurations)))

# Quick and dirty way of naming all our data table rows.
for i in range(len(projects)):
    sampleName = "Participant "+ str(i+1)
    for j in range(5):
        tableIndices.append(sampleName + " - session "+ str(j+1))
    tableIndices.append(sampleName + " - session average")
    tableIndices.append(sampleName + " -  composite sessions")

tableIndices.append("General average")
tableIndices.append("Composite all sessions")


df = pd.DataFrame(tableData, index = tableIndices)
display(df)
# Out:
# Number of excluded measurements: 8
#                                      Minimum pixel value rel. StDev [%]  \
# Participant 1 - session 1                                      3.421705
# Participant 1 - session 2                                      2.558949
# Participant 1 - session 3                                      2.556727
# Participant 1 - session 4                                      3.054457
# Participant 1 - session 5                                      2.017273
# Participant 1 - session average                                2.721822
# Participant 1 -  composite sessions                            3.380769
# Participant 2 - session 1                                      4.105808
# Participant 2 - session 2                                      4.222252
# Participant 2 - session 3                                      1.507332
# Participant 2 - session 4                                      2.101271
# Participant 2 - session 5                                      6.042263
# Participant 2 - session average                                3.595785
# Participant 2 -  composite sessions                            4.421453
# Participant 3 - session 1                                      4.395210
# Participant 3 - session 2                                      2.978666
# Participant 3 - session 3                                      2.481340
# Participant 3 - session 4                                      1.973316
# Participant 3 - session 5                                      2.411362
# Participant 3 - session average                                2.847979
# Participant 3 -  composite sessions                            3.549592
# Participant 4 - session 1                                      8.482186
# Participant 4 - session 2                                      4.917366
# Participant 4 - session 3                                      8.157929
# Participant 4 - session 4                                      9.428098
# Participant 4 - session 5                                      6.931509
# Participant 4 - session average                                7.583418
# Participant 4 -  composite sessions                            8.308231
# Participant 5 - session 1                                      6.809798
# Participant 5 - session 2                                      9.669039
# Participant 5 - session 3                                      3.666155
# Participant 5 - session 4                                      6.457306
# Participant 5 - session 5                                      8.331813
# Participant 5 - session average                                6.986822
# Participant 5 -  composite sessions                            8.223831
# Participant 6 - session 1                                      2.697298
# Participant 6 - session 2                                      2.158198
# Participant 6 - session 3                                      2.730227
# Participant 6 - session 4                                      2.562606
# Participant 6 - session 5                                      2.144304
# Participant 6 - session average                                2.458527
# Participant 6 -  composite sessions                            3.092055
# Participant 7 - session 1                                      3.798465
# Participant 7 - session 2                                      4.829933
# Participant 7 - session 3                                      3.157605
# Participant 7 - session 4                                      4.071004
# Participant 7 - session 5                                      7.341903
# Participant 7 - session average                                4.639782
# Participant 7 -  composite sessions                            5.309906
# Participant 8 - session 1                                      8.164044
# Participant 8 - session 2                                      4.459307
# Participant 8 - session 3                                      6.321708
# Participant 8 - session 4                                      4.628754
# Participant 8 - session 5                                      8.045449
# Participant 8 - session average                                6.323852
# Participant 8 -  composite sessions                            7.471909
# General average                                                4.644748
# Composite all sessions                                         6.299941
#
#                                      Maximum pixel value rel. StDev [%]  \
# Participant 1 - session 1                                      0.520075
# Participant 1 - session 2                                      0.350228
# Participant 1 - session 3                                      0.350290
# Participant 1 - session 4                                      0.523229
# Participant 1 - session 5                                      0.268079
# Participant 1 - session average                                0.402380
# Participant 1 -  composite sessions                            0.514903
# Participant 2 - session 1                                      0.458871
# Participant 2 - session 2                                      0.414833
# Participant 2 - session 3                                      0.248109
# Participant 2 - session 4                                      0.414153
# Participant 2 - session 5                                      1.128854
# Participant 2 - session average                                0.532964
# Participant 2 -  composite sessions                            0.749144
# Participant 3 - session 1                                      0.782168
# Participant 3 - session 2                                      0.497475
# Participant 3 - session 3                                      0.295306
# Participant 3 - session 4                                      0.252044
# Participant 3 - session 5                                      0.400398
# Participant 3 - session average                                0.445478
# Participant 3 -  composite sessions                            0.620526
# Participant 4 - session 1                                      2.560448
# Participant 4 - session 2                                      0.897550
# Participant 4 - session 3                                      2.034344
# Participant 4 - session 4                                      2.725858
# Participant 4 - session 5                                      2.108770
# Participant 4 - session average                                2.065394
# Participant 4 -  composite sessions                            2.880781
# Participant 5 - session 1                                      1.712192
# Participant 5 - session 2                                      2.649619
# Participant 5 - session 3                                      0.993825
# Participant 5 - session 4                                      1.704582
# Participant 5 - session 5                                      2.009932
# Participant 5 - session average                                1.814030
# Participant 5 -  composite sessions                            2.801949
# Participant 6 - session 1                                      0.355318
# Participant 6 - session 2                                      0.261414
# Participant 6 - session 3                                      0.384142
# Participant 6 - session 4                                      0.397621
# Participant 6 - session 5                                      0.287478
# Participant 6 - session average                                0.337194
# Participant 6 -  composite sessions                            0.465443
# Participant 7 - session 1                                      0.440543
# Participant 7 - session 2                                      0.799950
# Participant 7 - session 3                                      0.578840
# Participant 7 - session 4                                      0.502596
# Participant 7 - session 5                                      0.923829
# Participant 7 - session average                                0.649152
# Participant 7 -  composite sessions                            0.842017
# Participant 8 - session 1                                      2.474364
# Participant 8 - session 2                                      0.767653
# Participant 8 - session 3                                      1.307098
# Participant 8 - session 4                                      0.772511
# Participant 8 - session 5                                      1.561356
# Participant 8 - session average                                1.376596
# Participant 8 -  composite sessions                            2.193183
# General average                                                0.952899
# Composite all sessions                                         2.116663
#
#                                      Mean pixel value rel. StDev [%]  \
# Participant 1 - session 1                                   0.505082
# Participant 1 - session 2                                   0.343467
# Participant 1 - session 3                                   0.318691
# Participant 1 - session 4                                   0.426037
# Participant 1 - session 5                                   0.264743
# Participant 1 - session average                             0.371604
# Participant 1 -  composite sessions                         0.472990
# Participant 2 - session 1                                   0.678283
# Participant 2 - session 2                                   0.637762
# Participant 2 - session 3                                   0.326734
# Participant 2 - session 4                                   0.500125
# Participant 2 - session 5                                   1.149079
# Participant 2 - session average                             0.658397
# Participant 2 -  composite sessions                         0.803047
# Participant 3 - session 1                                   0.731389
# Participant 3 - session 2                                   0.440484
# Participant 3 - session 3                                   0.368031
# Participant 3 - session 4                                   0.306460
# Participant 3 - session 5                                   0.407807
# Participant 3 - session average                             0.450834
# Participant 3 -  composite sessions                         0.564366
# Participant 4 - session 1                                   2.254209
# Participant 4 - session 2                                   0.854698
# Participant 4 - session 3                                   1.989205
# Participant 4 - session 4                                   2.454029
# Participant 4 - session 5                                   1.527447
# Participant 4 - session average                             1.815918
# Participant 4 -  composite sessions                         2.126524
# Participant 5 - session 1                                   1.547032
# Participant 5 - session 2                                   2.353275
# Participant 5 - session 3                                   0.735604
# Participant 5 - session 4                                   1.442500
# Participant 5 - session 5                                   1.873701
# Participant 5 - session average                             1.590423
# Participant 5 -  composite sessions                         2.040644
# Participant 6 - session 1                                   0.488812
# Participant 6 - session 2                                   0.270792
# Participant 6 - session 3                                   0.366917
# Participant 6 - session 4                                   0.336843
# Participant 6 - session 5                                   0.281437
# Participant 6 - session average                             0.348960
# Participant 6 -  composite sessions                         0.465053
# Participant 7 - session 1                                   0.565239
# Participant 7 - session 2                                   0.855667
# Participant 7 - session 3                                   0.505082
# Participant 7 - session 4                                   0.611327
# Participant 7 - session 5                                   1.597176
# Participant 7 - session average                             0.826898
# Participant 7 -  composite sessions                         1.030402
# Participant 8 - session 1                                   2.206905
# Participant 8 - session 2                                   0.683255
# Participant 8 - session 3                                   1.197237
# Participant 8 - session 4                                   0.759990
# Participant 8 - session 5                                   1.622864
# Participant 8 - session average                             1.294050
# Participant 8 -  composite sessions                         1.684141
# General average                                             0.919636
# Composite all sessions                                      1.457130
#
#                                      X-coordinate StDev [px]  \
# Participant 1 - session 1                           0.532570
# Participant 1 - session 2                           0.394807
# Participant 1 - session 3                           0.373030
# Participant 1 - session 4                           0.531601
# Participant 1 - session 5                           0.311391
# Participant 1 - session average                     0.428680
# Participant 1 -  composite sessions                 0.502454
# Participant 2 - session 1                           0.601960
# Participant 2 - session 2                           0.468493
# Participant 2 - session 3                           0.489051
# Participant 2 - session 4                           0.630643
# Participant 2 - session 5                           0.804472
# Participant 2 - session average                     0.598924
# Participant 2 -  composite sessions                 0.620490
# Participant 3 - session 1                           0.555674
# Participant 3 - session 2                           0.526247
# Participant 3 - session 3                           0.508087
# Participant 3 - session 4                           0.402641
# Participant 3 - session 5                           0.450360
# Participant 3 - session average                     0.488602
# Participant 3 -  composite sessions                 0.545781
# Participant 4 - session 1                           0.873463
# Participant 4 - session 2                           0.500404
# Participant 4 - session 3                           0.844786
# Participant 4 - session 4                           1.267706
# Participant 4 - session 5                           0.880278
# Participant 4 - session average                     0.873328
# Participant 4 -  composite sessions                 1.004973
# Participant 5 - session 1                           1.308030
# Participant 5 - session 2                           1.017879
# Participant 5 - session 3                           0.549665
# Participant 5 - session 4                           1.130661
# Participant 5 - session 5                           1.207036
# Participant 5 - session average                     1.042654
# Participant 5 -  composite sessions                 1.183530
# Participant 6 - session 1                           0.477412
# Participant 6 - session 2                           0.288078
# Participant 6 - session 3                           0.363057
# Participant 6 - session 4                           0.442241
# Participant 6 - session 5                           0.243237
# Participant 6 - session average                     0.362805
# Participant 6 -  composite sessions                 0.438668
# Participant 7 - session 1                           0.631483
# Participant 7 - session 2                           0.601945
# Participant 7 - session 3                           0.540861
# Participant 7 - session 4                           0.432087
# Participant 7 - session 5                           0.773452
# Participant 7 - session average                     0.595966
# Participant 7 -  composite sessions                 0.621877
# Participant 8 - session 1                           1.249819
# Participant 8 - session 2                           0.569783
# Participant 8 - session 3                           0.670718
# Participant 8 - session 4                           0.437610
# Participant 8 - session 5                           0.890495
# Participant 8 - session average                     0.763685
# Participant 8 -  composite sessions                 0.835787
# General average                                     0.644330
# Composite all sessions                              0.791937
#
#                                      Y-coordinate StDev [px]  \
# Participant 1 - session 1                           0.633220
# Participant 1 - session 2                           0.473409
# Participant 1 - session 3                           0.403153
# Participant 1 - session 4                           0.559711
# Participant 1 - session 5                           0.331054
# Participant 1 - session average                     0.480110
# Participant 1 -  composite sessions                 0.519505
# Participant 2 - session 1                           0.627334
# Participant 2 - session 2                           0.696771
# Participant 2 - session 3                           0.373868
# Participant 2 - session 4                           0.535359
# Participant 2 - session 5                           0.899240
# Participant 2 - session average                     0.626514
# Participant 2 -  composite sessions                 0.689390
# Participant 3 - session 1                           0.758785
# Participant 3 - session 2                           0.602750
# Participant 3 - session 3                           0.513452
# Participant 3 - session 4                           0.404578
# Participant 3 - session 5                           0.671259
# Participant 3 - session average                     0.590165
# Participant 3 -  composite sessions                 0.627887
# Participant 4 - session 1                           1.376756
# Participant 4 - session 2                           0.746502
# Participant 4 - session 3                           1.435927
# Participant 4 - session 4                           1.647484
# Participant 4 - session 5                           1.318688
# Participant 4 - session average                     1.305071
# Participant 4 -  composite sessions                 1.408398
# Participant 5 - session 1                           0.929199
# Participant 5 - session 2                           1.523545
# Participant 5 - session 3                           0.847571
# Participant 5 - session 4                           0.996193
# Participant 5 - session 5                           1.004741
# Participant 5 - session average                     1.060250
# Participant 5 -  composite sessions                 1.280420
# Participant 6 - session 1                           0.594610
# Participant 6 - session 2                           0.375330
# Participant 6 - session 3                           0.446944
# Participant 6 - session 4                           0.447759
# Participant 6 - session 5                           0.428387
# Participant 6 - session average                     0.458606
# Participant 6 -  composite sessions                 0.503353
# Participant 7 - session 1                           0.561500
# Participant 7 - session 2                           0.644732
# Participant 7 - session 3                           0.473158
# Participant 7 - session 4                           0.643132
# Participant 7 - session 5                           0.783866
# Participant 7 - session average                     0.621278
# Participant 7 -  composite sessions                 0.657337
# Participant 8 - session 1                           1.087620
# Participant 8 - session 2                           0.744154
# Participant 8 - session 3                           0.891537
# Participant 8 - session 4                           0.564240
# Participant 8 - session 5                           1.072375
# Participant 8 - session average                     0.871985
# Participant 8 -  composite sessions                 1.031980
# General average                                     0.751747
# Composite all sessions                              0.997896
#
#                                      Average duration [sec]  \
# Participant 1 - session 1                         52.200000
# Participant 1 - session 2                         51.900000
# Participant 1 - session 3                         42.300000
# Participant 1 - session 4                         42.500000
# Participant 1 - session 5                         40.000000
# Participant 1 - session average                   45.780000
# Participant 1 -  composite sessions               45.780000
# Participant 2 - session 1                         42.600000
# Participant 2 - session 2                         39.500000
# Participant 2 - session 3                         44.700000
# Participant 2 - session 4                         43.800000
# Participant 2 - session 5                         59.300000
# Participant 2 - session average                   45.980000
# Participant 2 -  composite sessions               45.980000
# Participant 3 - session 1                         54.500000
# Participant 3 - session 2                         46.500000
# Participant 3 - session 3                         47.900000
# Participant 3 - session 4                         46.900000
# Participant 3 - session 5                         50.400000
# Participant 3 - session average                   49.240000
# Participant 3 -  composite sessions               49.240000
# Participant 4 - session 1                         46.000000
# Participant 4 - session 2                         44.100000
# Participant 4 - session 3                         36.300000
# Participant 4 - session 4                         32.666667
# Participant 4 - session 5                         31.800000
# Participant 4 - session average                   38.173333
# Participant 4 -  composite sessions               38.173333
# Participant 5 - session 1                         42.888889
# Participant 5 - session 2                         44.375000
# Participant 5 - session 3                         33.700000
# Participant 5 - session 4                         29.000000
# Participant 5 - session 5                         22.700000
# Participant 5 - session average                   34.532778
# Participant 5 -  composite sessions               34.532778
# Participant 6 - session 1                         96.600000
# Participant 6 - session 2                         98.100000
# Participant 6 - session 3                         83.800000
# Participant 6 - session 4                        164.500000
# Participant 6 - session 5                         88.700000
# Participant 6 - session average                  106.340000
# Participant 6 -  composite sessions              106.340000
# Participant 7 - session 1                        120.600000
# Participant 7 - session 2                         59.800000
# Participant 7 - session 3                         61.100000
# Participant 7 - session 4                         51.800000
# Participant 7 - session 5                         61.900000
# Participant 7 - session average                   71.040000
# Participant 7 -  composite sessions               71.040000
# Participant 8 - session 1                         71.500000
# Participant 8 - session 2                         54.600000
# Participant 8 - session 3                         40.300000
# Participant 8 - session 4                         42.100000
# Participant 8 - session 5                         45.500000
# Participant 8 - session average                   50.800000
# Participant 8 -  composite sessions               50.800000
# General average                                   55.235764
# Composite all sessions                            55.235764
#
#                                      Duration StDev [sec]
# Participant 1 - session 1                       13.464356
# Participant 1 - session 2                        8.252272
# Participant 1 - session 3                       10.022752
# Participant 1 - session 4                        8.168367
# Participant 1 - session 5                        6.716481
# Participant 1 - session average                  9.324846
# Participant 1 -  composite sessions              5.808356
# Participant 2 - session 1                        4.501851
# Participant 2 - session 2                        7.230337
# Participant 2 - session 3                       19.032428
# Participant 2 - session 4                        7.899367
# Participant 2 - session 5                       21.103186
# Participant 2 - session average                 11.953434
# Participant 2 -  composite sessions              7.701104
# Participant 3 - session 1                       13.769935
# Participant 3 - session 2                       12.868998
# Participant 3 - session 3                       10.224698
# Participant 3 - session 4                        7.109462
# Participant 3 - session 5                        9.500877
# Participant 3 - session average                 10.694794
# Participant 3 -  composite sessions              3.308776
# Participant 4 - session 1                       18.193405
# Participant 4 - session 2                        5.971227
# Participant 4 - session 3                        9.286190
# Participant 4 - session 4                        8.108637
# Participant 4 - session 5                        6.528570
# Participant 4 - session average                  9.617606
# Participant 4 -  composite sessions              6.535178
# Participant 5 - session 1                       14.928533
# Participant 5 - session 2                       15.305811
# Participant 5 - session 3                       11.785584
# Participant 5 - session 4                        7.516648
# Participant 5 - session 5                        2.110819
# Participant 5 - session average                 10.329479
# Participant 5 -  composite sessions              9.192575
# Participant 6 - session 1                       21.838803
# Participant 6 - session 2                       17.885127
# Participant 6 - session 3                       13.011106
# Participant 6 - session 4                      155.785643
# Participant 6 - session 5                       22.813495
# Participant 6 - session average                 46.266835
# Participant 6 -  composite sessions             33.032454
# Participant 7 - session 1                       46.149997
# Participant 7 - session 2                       14.898173
# Participant 7 - session 3                       13.939951
# Participant 7 - session 4                       32.642168
# Participant 7 - session 5                       14.880636
# Participant 7 - session average                 24.502185
# Participant 7 -  composite sessions             27.995768
# Participant 8 - session 1                       15.390164
# Participant 8 - session 2                       10.437113
# Participant 8 - session 3                        4.738729
# Participant 8 - session 4                        6.806043
# Participant 8 - session 5                        5.482295
# Participant 8 - session average                  8.570869
# Participant 8 -  composite sessions             12.815615
# General average                                 16.407506
# Composite all sessions                          26.861809
